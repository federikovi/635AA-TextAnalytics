# %% [markdown]
# # Cleaning training set

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
from time import time
from bs4 import BeautifulSoup
from ekphrasis.classes.preprocessor import TextPreProcessor
from ekphrasis.classes.tokenizer import SocialTokenizer
from ekphrasis.dicts.emoticons import emoticons

# %%
columns = ['polarity', 'id', 'date', 'query_type', 'user', 'text']

dftrain = pd.read_csv('csv/training.1600000.processed.noemoticon.csv',
                     header = None, 
                     usecols = [0,5], 
                     names=columns,
                     encoding ='ISO-8859-1')

# %%
dftrain.head()
# Out:
#    polarity                                               text
# 0         0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1         0  is upset that he can't update his Facebook by ...
# 2         0  @Kenichan I dived many times for the ball. Man...
# 3         0    my whole body feels itchy and like its on fire
# 4         0  @nationwideclass no, it's not behaving at all....

# %%
len(dftrain)
# Out:
# 1600000

# %% [markdown]
# #### Verifying tweets' length

# %%
dftrain['length'] = [len(t) for t in dftrain.text]

# %%
dftrain[dftrain.length >140].head(100)
# Out:
#        polarity                                               text  length
# 213           0  Awwh babs... you look so sad underneith that s...     142
# 226           0  Tuesdayï¿½ll start with reflection ï¿½n then a...     141
# 279           0  Whinging. My client&amp;boss don't understand ...     145
# 343           0  @TheLeagueSF Not Fun &amp; Furious? The new ma...     145
# 400           0  #3 woke up and was having an accident - &quot;...     144
# 464           0  My bathtub drain is fired: it haz 1 job 2 do, ...     146
# 492           0  pears &amp; Brie, bottle of Cabernet, and &quo...     150
# 747           0  Have an invite for &quot;Healthy Dining&quot; ...     141
# 957           0  Damnit I was really digging this season of Rea...     141
# 1064          0  Why do I keep looking...I know that what I rea...     141
# 1071          0  Used the term &quot;Fail Whale&quot; to a clie...     148
# 1086          0  @transbay &quot;SFMTA Budget Proposal Hearing:...     141
# 1135          0  today is day 1 of my fast &amp; i feel i may b...     141
# 1380          0  @Craftysince1990 Lol, that's sweet! I bought t...     144
# 1612          0  Oh no!!!!!!!!!!!!! @AzPPA just sent email for ...     141
# 1704          0  @ktml I think its iTunes fault I cant download...     145
# 1745          0  I am layin in bed @ 3am cos my tummy is beatbo...     147
# 1750          0  thinks factorial designs are going to be the d...     141
# 1767          0  tks pa 4 &quot;tapauing&quot; croissant tuna k...     152
# 1939          0  @msJodiOdie its such a sad situation. Though 1...     142
# 2182          0  okay bbs &lt;3 does anyone know where i can ge...     141
# 2210          0  @MsTyraC lol yea I thought about tht ..sowey  ...     142
# 2432          0  will have a meeting in an hour to explain &quo...     147
# 2487          0  flat out today didnt get everythin done &amp; ...     146
# 2553          0  this is exactly why as cities burn worries me ...     142
# 2643          0  @duskyazure least U got 2 lie in - I 've bn up...     141
# 2666          0  Finished marking can't celebrate yet tho, got ...     141
# 2838          0  @outoutout dunno..I've emailed their website +...     141
# 3140          0  When I get mine Iï¿½m going to do a tour of Co...     142
# 3313          0  Amber i don't know how often you check this, b...     142
# ...         ...                                                ...     ...
# 8034          0  Rock Fore Dough is tonight &amp; I'm missing i...     142
# 8054          0  r.i.p. fave jeans. If you weren't discontinued...     142
# 8119          0  @shamzleroc ooooh!  I wanna come. I was BUSSIN...     146
# 8123          0  : Gosh, I'm fucking emo. I wrote on status on ...     141
# 8247          0  @Jennnymay &quot;JennnymayI had a dream that @...     147
# 8314          0  @tgadget Thanks for your tweet, but I am   Hop...     148
# 8458          0  @studio_gal Oh! And my friend, Carole Shelley,...     144
# 8528          0  twitter spam - seeing messages that start with...     143
# 8711          0  @mischaarmada So today some girl walked into t...     145
# 8843          0  i'm tagging all my LJ entries &amp; i came acr...     144
# 8934          0  @EmilyK4 the sec on the left, opposite side of...     142
# 9007          0  @DdotRock my friends forced it back on my tv. ...     146
# 9080          0  @tm_lv gacias... you opened my eyes... Well, I...     147
# 9153          0  btw, T made it home okay. 2 glasses of wine &a...     142
# 9242          0  Anyone else sick of folks who don't understand...     142
# 9315          0  @superdaveyboy  Wish I could do something to h...     148
# 9463          0  forgot about surry hills fest  but managed to ...     148
# 9476          0  Wont go back to KFC for a while.  Where KFC fa...     148
# 9559          0  OK-I have to get off twitter-got 2 get up earl...     142
# 9803          0  @OhhMegg no wonder  &amp; PLUS did you know th...     141
# 9842          0  I'm dyingggg. My kid has a taser inside of my ...     148
# 9953          0  now i have a new problem... don't know which t...     142
# 9954          0  Heading to Marsh to pick up Jakob's cake for t...     148
# 9976          0  @mileycyrus i was reading your book today &amp...     142
# 10069         0  @JaccSparrow Are you sleeping in or something,...     142
# 10111         0  @mileycyrus Iï¿½d like to go to Madrid to see ...     149
# 10226         0  Is it just me or are the two guys on that seri...     148
# 10507         0  I must be feeling a bit better today! My sense...     148
# 10655         0  thatï¿½s what I call a &quot;suboptimal&quot; ...     148
# 10668         0  OMJ the Jonas Brothers still are NOT comming t...     142
#
# [100 rows x 3 columns]

# %%
len(dftrain[dftrain.length >140])
# Out:
# 17174

# %%
# %%time
souped_tweets = []
for i in dftrain['text']:
    soup = BeautifulSoup(i, 'lxml')
    souped = soup.get_text()
    souped_tweets.append(souped)
# Out:
# CPU times: user 4min 28s, sys: 17.8 s, total: 4min 45s
# Wall time: 4min 46s

# %%
dftrain['bom_text'] = [t for t in souped_tweets]

# %%
dftrain.head()
# Out:
#    polarity                                               text  length  \
# 0         0  @switchfoot http://twitpic.com/2y1zl - Awww, t...     115
# 1         0  is upset that he can't update his Facebook by ...     111
# 2         0  @Kenichan I dived many times for the ball. Man...      89
# 3         0    my whole body feels itchy and like its on fire       47
# 4         0  @nationwideclass no, it's not behaving at all....     111
#
#                                             bom_text
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1  is upset that he can't update his Facebook by ...
# 2  @Kenichan I dived many times for the ball. Man...
# 3    my whole body feels itchy and like its on fire
# 4  @nationwideclass no, it's not behaving at all....

# %%
bom_train = dftrain[['bom_text', 'polarity']].copy()

# %%
bom_train.head()
# Out:
#                                             bom_text  polarity
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, t...         0
# 1  is upset that he can't update his Facebook by ...         0
# 2  @Kenichan I dived many times for the ball. Man...         0
# 3    my whole body feels itchy and like its on fire          0
# 4  @nationwideclass no, it's not behaving at all....         0

# %%
bom_train['length'] = [len(t) for t in bom_train.bom_text]

# %%
bom_train.tail()
# Out:
#                                                   bom_text  polarity  length
# 1599995  Just woke up. Having no school is the best fee...         4      56
# 1599996  TheWDB.com - Very cool to hear old Walt interv...         4      78
# 1599997  Are you ready for your MoJo Makeover? Ask me f...         4      57
# 1599998  Happy 38th Birthday to my boo of alll time!!! ...         4      65
# 1599999  happy #charitytuesday @theNSPCC @SparksCharity...         4      62

# %%
bom_train[bom_train.length >140].count()
# Out:
# bom_text    687
# polarity    687
# length      687
# dtype: int64

# %% [markdown]
# #### Removing tweets having length > 140

# %%
df_tweets = bom_train.drop(bom_train[bom_train.length >140].index)

# %%
len(df_tweets)
# Out:
# 1599313

# %% [markdown]
# #### Applying Ekphrasis Library for cleaning dataset
#
# - substitute URLs with tag `<url>`
# - substitute emails with tag `<email>`
# - substitute mentions with tag `<user>`
# - remove percent, money, phone, time, date, number

# %%
# %%time

text_processor = TextPreProcessor(
    # terms that will be normalized
    normalize=['url', 'email', 'percent', 'money', 'phone', 'user',
        'time', 'date', 'number'],
    # terms that will be annotated
    annotate={"elongated", "repeated"},
    fix_html=True,  # fix HTML tokens
    
    # corpus from which the word statistics are going to be used 
    # for word segmentation 
    segmenter="twitter", 
    
    # corpus from which the word statistics are going to be used 
    # for spell correction
    corrector="twitter", 
    
    unpack_hashtags=True,  # perform word segmentation on hashtags
    unpack_contractions=True,  # Unpack contractions (can't -> can not)
    spell_correct_elong=False,  # spell correction for elongated word
    
    # select a tokenizer. You can use SocialTokenizer, or pass your own
    # the tokenizer, should take as input a string and return a list of tokens
    tokenizer=SocialTokenizer(lowercase=True).tokenize,
    
    # list of dictionaries, for replacing tokens extracted from the text,
    # with other expressions. You can pass more than one dictionaries.
    dicts=[emoticons]
)

normalized_text = []

for s in df_tweets['bom_text']:
    normalized_text.append(" ".join(text_processor.pre_process_doc(s)))
normalized_text_series = pd.Series(normalized_text)
# Out:
# Reading twitter - 1grams ...
# Reading twitter - 2grams ...
# Reading twitter - 1grams ...
# CPU times: user 6min 6s, sys: 1.14 s, total: 6min 7s
# Wall time: 6min 8s

# %%
df_tweets['normalized_text'] = [t for t in normalized_text_series]

# %%
df_tweets.head()
# Out:
#                                             bom_text  polarity  length  \
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, t...         0     115
# 1  is upset that he can't update his Facebook by ...         0     111
# 2  @Kenichan I dived many times for the ball. Man...         0      89
# 3    my whole body feels itchy and like its on fire          0      47
# 4  @nationwideclass no, it's not behaving at all....         0     111
#
#                                      normalized_text
# 0  <user> <url> - aw <elongated> , that ' s a bum...
# 1  is upset that he can not update his facebook b...
# 2  <user> i dived many times for the ball . manag...
# 3     my whole body feels itchy and like its on fire
# 4  <user> no , it ' s not behaving at all . i am ...

# %%
len(df_tweets)
# Out:
# 1599313

# %%
df_len_tweets = df_tweets[['normalized_text', 'polarity']].copy()
df_len_tweets.head()
# Out:
#                                      normalized_text  polarity
# 0  <user> <url> - aw <elongated> , that ' s a bum...         0
# 1  is upset that he can not update his facebook b...         0
# 2  <user> i dived many times for the ball . manag...         0
# 3     my whole body feels itchy and like its on fire         0
# 4  <user> no , it ' s not behaving at all . i am ...         0

# %%
df_len_tweets['length'] = [len(t) for t in df_len_tweets.normalized_text]
df_len_tweets.head()
# Out:
#                                      normalized_text  polarity  length
# 0  <user> <url> - aw <elongated> , that ' s a bum...         0     109
# 1  is upset that he can not update his facebook b...         0     124
# 2  <user> i dived many times for the ball . manag...         0      92
# 3     my whole body feels itchy and like its on fire         0      46
# 4  <user> no , it ' s not behaving at all . i am ...         0     110

# %%
df_len_tweets.length.max()
# Out:
# 359

# %%
# %%time
user_tweets = []

for t in df_len_tweets.normalized_text:
    user_tweets.append(t.replace('<user>', '@USER'))

df_len_tweets['text_no_user'] = [t for t in user_tweets]
# Out:
# CPU times: user 1.16 s, sys: 97 ms, total: 1.25 s
# Wall time: 1.25 s

# %%
df_len_tweets.head()
# Out:
#                                      normalized_text  polarity  length  \
# 0  <user> <url> - aw <elongated> , that ' s a bum...         0     109
# 1  is upset that he can not update his facebook b...         0     124
# 2  <user> i dived many times for the ball . manag...         0      92
# 3     my whole body feels itchy and like its on fire         0      46
# 4  <user> no , it ' s not behaving at all . i am ...         0     110
#
#                                         text_no_user
# 0  @USER <url> - aw <elongated> , that ' s a bumm...
# 1  is upset that he can not update his facebook b...
# 2  @USER i dived many times for the ball . manage...
# 3     my whole body feels itchy and like its on fire
# 4  @USER no , it ' s not behaving at all . i am m...

# %%
url_tweets = []
for t in df_len_tweets.text_no_user:
    #print(df_len_tweets.text[i].replace(s, ''))
    url_tweets.append(t.replace('<url>', '@URL'))

df_len_tweets['text_no_url'] = [t for t in url_tweets]

# %%
df_len_tweets.head()
# Out:
#                                      normalized_text  polarity  length  \
# 0  <user> <url> - aw <elongated> , that ' s a bum...         0     109
# 1  is upset that he can not update his facebook b...         0     124
# 2  <user> i dived many times for the ball . manag...         0      92
# 3     my whole body feels itchy and like its on fire         0      46
# 4  <user> no , it ' s not behaving at all . i am ...         0     110
#
#                                         text_no_user  \
# 0  @USER <url> - aw <elongated> , that ' s a bumm...
# 1  is upset that he can not update his facebook b...
# 2  @USER i dived many times for the ball . manage...
# 3     my whole body feels itchy and like its on fire
# 4  @USER no , it ' s not behaving at all . i am m...
#
#                                          text_no_url
# 0  @USER @URL - aw <elongated> , that ' s a bumme...
# 1  is upset that he can not update his facebook b...
# 2  @USER i dived many times for the ball . manage...
# 3     my whole body feels itchy and like its on fire
# 4  @USER no , it ' s not behaving at all . i am m...

# %%
# %%time
notag_tweets = []
for t in df_len_tweets.text_no_url:
    #print(df_len_tweets.text[i].replace(s, ''))
    notag_tweets.append(re.sub(r'(<[aA-zZ]+>)', '',t))

df_len_tweets['text_no_tag'] = [t for t in notag_tweets]
# Out:
# CPU times: user 2.13 s, sys: 72.3 ms, total: 2.2 s
# Wall time: 2.2 s

# %%
df_len_tweets.head()
# Out:
#                                      normalized_text  polarity  length  \
# 0  <user> <url> - aw <elongated> , that ' s a bum...         0     109
# 1  is upset that he can not update his facebook b...         0     124
# 2  <user> i dived many times for the ball . manag...         0      92
# 3     my whole body feels itchy and like its on fire         0      46
# 4  <user> no , it ' s not behaving at all . i am ...         0     110
#
#                                         text_no_user  \
# 0  @USER <url> - aw <elongated> , that ' s a bumm...
# 1  is upset that he can not update his facebook b...
# 2  @USER i dived many times for the ball . manage...
# 3     my whole body feels itchy and like its on fire
# 4  @USER no , it ' s not behaving at all . i am m...
#
#                                          text_no_url  \
# 0  @USER @URL - aw <elongated> , that ' s a bumme...
# 1  is upset that he can not update his facebook b...
# 2  @USER i dived many times for the ball . manage...
# 3     my whole body feels itchy and like its on fire
# 4  @USER no , it ' s not behaving at all . i am m...
#
#                                          text_no_tag
# 0  @USER @URL - aw  , that ' s a bummer . you sho...
# 1  is upset that he can not update his facebook b...
# 2  @USER i dived many times for the ball . manage...
# 3     my whole body feels itchy and like its on fire
# 4  @USER no , it ' s not behaving at all . i am m...

# %%
finaltrain = df_len_tweets[['text_no_tag', 'polarity']].copy()

# %%
finaltrain.head()
# Out:
#                                          text_no_tag  polarity
# 0  @USER @URL - aw  , that ' s a bummer . you sho...         0
# 1  is upset that he can not update his facebook b...         0
# 2  @USER i dived many times for the ball . manage...         0
# 3     my whole body feels itchy and like its on fire         0
# 4  @USER no , it ' s not behaving at all . i am m...         0

# %%
finaltrain['length'] = [len(t) for t in finaltrain.text_no_tag]
finaltrain.head()
# Out:
#                                          text_no_tag  polarity  length
# 0  @USER @URL - aw  , that ' s a bummer . you sho...         0      90
# 1  is upset that he can not update his facebook b...         0     114
# 2  @USER i dived many times for the ball . manage...         0      82
# 3     my whole body feels itchy and like its on fire         0      46
# 4  @USER no , it ' s not behaving at all . i am m...         0     109

# %%
len(finaltrain)
# Out:
# 1599313

# %%
finaltrain[finaltrain.text_no_tag == '@USER'].count()
# Out:
# text_no_tag    2673
# polarity       2673
# length         2673
# dtype: int64

# %%
finaltrain[finaltrain.text_no_tag == '@URL'].count()
# Out:
# text_no_tag    22
# polarity       22
# length         22
# dtype: int64

# %%
finaltrain[finaltrain.text_no_tag == '@USER @URL'].count()
# Out:
# text_no_tag    70
# polarity       70
# length         70
# dtype: int64

# %%
finaltrain[finaltrain.text_no_tag == '@URL @USER'].count()
# Out:
# text_no_tag    0
# polarity       0
# length         0
# dtype: int64

# %%
finaltrain[finaltrain.length == 0].count()
# Out:
# text_no_tag    3
# polarity       3
# length         3
# dtype: int64

# %%
finaltrain[finaltrain.length >140]
# Out:
#                                                text_no_tag  polarity  length
# 76       @USER my donkey is sensitive about such commen...         0     142
# 93       pray for me please , the ex is threatening to ...         0     141
# 126      @USER wah i can not see clip , must be el - st...         0     146
# 279      whinging . my client & boss do not understand ...         0     148
# 327      .  and of course .  i have access to my halo  ...         0     143
# 348      still sick . feeling a bit better , got some n...         0     143
# 400      #  woke up and was having an accident - " it '...         0     142
# 407      why to we , the only school in the world , be ...         0     144
# 464      my bathtub drain is fired : it haz  job  do , ...         0     142
# 527      can not sleep again . face is kinda swollen . ...         0     144
# 696      just finished a delicious breakfast , my last ...         0     143
# 779      there ' s a new kind of starburst : favereds ....         0     144
# 824      sittin here w / kayla , i really really really...         0     146
# 826      ' s kinda bummed . an agency just told me that...         0     145
# 912      off to london for the day on thursday , it ' s...         0     147
# 958      gah , comcast doubled our cable / internet bil...         0     144
# 1064     why do i keep looking .  i know that what i re...         0     141
# 1131     ooops . just ate a panini from w - mart cold t...         0     144
# 1141     mum ' s been taken to hospital , they do not k...         0     142
# 1229     w / every person there . i did not get a pic m...         0     142
# 1297     train rammed , fellow commuters vile . special...         0     141
# 1420     i nearly spoiled myself for house , did just a...         0     143
# 1465090  @USER hello , em add ä  c bao nhiãªu friend t...         4     163
# 1465580  @USER ø³ø ¨ ø ­ ø § ù  ø § ù  ù  ù  ù  ø ...         4     170
# 1467586  @USER ×  × ? × § × ¨ ×  ×  ×  ×  × ? ×  ...         4     189
# 1468951  hã ¨ rã¹i .  mã¹a cã ¡ kiáº ¿ m ä  áº ¿ n rã¹...         4     164
# 1469161  @USER ñ ? ð ¿ ð ° ñ ? ð ¸ ð ± ð¾ iphone , ðºð¾...         4     178
# 1478942  æ   è ¦ ? ä ¸  æ  ¨ äº  ! å ¸  æ   å ¤...         4     201
# 1479328  @USER ð  ñ ? ðºð ¸ ð½ñ  ð ¡ ð  ð ¡ - ðºñ  ...         4     207
# 1482366  @USER ð³ð³ , ñ ? ð ¿ ð ° ñ ? ð ¸ ð ± ð¾ ð · ð ...         4     188
# 1489828  @USER ð½ðµ ñ ð¾ñ  ñ  ð · ð ° ñ  ð ¸ ñ  ð °...         4     186
# 1493003  @USER ø £ ù  ù  ø § ù ø § ø ° ø § øªù  øµø ...         4     167
# 1493675  thinking_in_java_ ( 4 th_edition ) - ðºñ  ñ ...         4     186
# 1497655  brooke - " frustrated " , " pissy " , " gr  " ...         4     162
# 1498018  ð  ð ¿ ð¾ñ  ðµð¼ñ  ð¼ð¾ð · ð³ð¾ð²ð¾ð¹ ñ  ñ...         4     162
# 1503440  @USER good morning ! æ  ¥ æ  ¬ èª  ã ? § ã ...         4     177
# 1516733  download summary : highs - fnm , sylosis , ope...         4     162
# 1524797  @USER î  î½ îµî ¯ î½î ± î¹ î ´ ï î½î ± ï  ï ...         4     161
# 1533761  @USER â  ¥ ~ â  ¢ * â  ¼â  ¥ â  « ~ . â ...         4     206
# 1560326  @USER i got a mail from cyworld " [ ì  ¸ ì ? ...         4     169
# 1565728  lol re - pu - b-l - i - can the demo - c - rat...         4     162
# 1584804  @USER ð  ð ° ð³ð¾ð » ð¾ð²ð¾ðº " lies , damn l...         4     162
# 1589911  @USER æ  ¥ ã   å  ºç  ºã  ? è ¡  è §  ...         4     161
# 1594133  @USER @USER parser echo preg_replace ( array (...         4     171
# 1595191  hm , 2 gb / 6 hours =  . 3 3 gb / hour ,  . 3 ...         4     170
#
# [170 rows x 3 columns]

# %%
finaltrain[finaltrain.length >160].count()
# Out:
# text_no_tag    170
# polarity       170
# length         170
# dtype: int64

# %% [markdown]
# Since tweets having length >= 140 are meaningful, we decided to drop tweets having length => 160 because they seem noisy. We also drop tweets with only @USER and @URL and having length == 0.

# %%
finaltrain = finaltrain.drop(finaltrain[(finaltrain.length >160) | (finaltrain.text_no_tag == '@USER') | (finaltrain.text_no_tag == '@URL') | (finaltrain.text_no_tag == '@USER @URL') | (finaltrain.length == 0)].index)

# %%
len(finaltrain)
# Out:
# 1596375

# %%
1600000 - 1596375
# Out:
# 3625

# %%
finaltrain.to_csv("finaltrain.csv")
